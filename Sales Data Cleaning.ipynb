# %% [markdown]
# # Import Necessary Libraries

# %%
# Get current working directory
import os
cwd = os.getcwd()

print(cwd)
# Out:
# C:\Users\cntondin\Documents\Pandas_Data_Science_Tasks_master\SalesAnalysis

# %% [markdown]
# ### Task 1: Merge the 12 months of sales into a single CSV file

# %%
import pandas as pd

# %%
df = pd.read_csv("./Sales_Data/Sales_April_2019.csv")

#df.head()

# %%
# Merge the all files:
 
files = [file for file in os.listdir('./sales_Data')]

#all_months_data = pd.DataFrame()

for file in files:
    name,extension = file.split('.')
  
    if extension == 'csv':
        df = pd.read_csv('./Sales_data/'+file)
        all_months_data = pd.concat([all_months_data, df])
    
all_months_data.to_csv('all_data.csv', index = False)


#all_months_data.head()

# %% [markdown]
# ### Read in updated dataframe

# %%
all_data = pd.read_csv('all_data.csv')
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ## Augment data with additional columns

# %% [markdown]
# ### Clean up all the NAN

# %%
# Create NAN dataframe



nan_df = all_data[all_data.isna().any(axis=1)]
all_data = all_data.dropna(how = 'all')

for i in all_data:
        if i == "Or":
            all_data = all_data.drop(all_data.index[(all_data["Order Date"] == "Or")],axis=0,inplace=True)


all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ### Convert date to string then to integer

# %%
all_data['Month'] = all_data['Order Date'].astype(str)

all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address           Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001  04/19/19 08:46
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215  04/07/19 22:30
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  04/12/19 14:38
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  04/12/19 14:38
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001  04/30/19 09:27

# %% [markdown]
# ### Strip spaces in Month column

# %%
all_data['Month'] = all_data['Month'].str.strip('Month')
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address           Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001  04/19/19 08:46
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215  04/07/19 22:30
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  04/12/19 14:38
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  04/12/19 14:38
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001  04/30/19 09:27

# %% [markdown]
# ### Exclude the month row

# %%
all_data= all_data[all_data["Month"] !='04/19/19 08:46']

all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
# 6   176562        USB-C Charging Cable                1      11.95
#
#        Order Date                        Purchase Address           Month
# 2  04/07/19 22:30       682 Chestnut St, Boston, MA 02215  04/07/19 22:30
# 3  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001  04/12/19 14:38
# 4  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001  04/12/19 14:38
# 5  04/30/19 09:27       333 8th St, Los Angeles, CA 90001  04/30/19 09:27
# 6  04/29/19 13:03  381 Wilson St, San Francisco, CA 94016  04/29/19 13:03
